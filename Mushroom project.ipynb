# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset1/master/mushrooms.csv")
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
df.shape
# Out:
# (8124, 23)

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
df.drop(['veil-type'],axis=1)
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # check balnace of edible and poisonous:

# %%
edible = df[df['class'] == "e"]["class"].count()
poisonous = df[df["class"] == "p"]["class"].count()
pe_ratio = poisonous/float(edible)
print(edible)
print(poisonous)
# Out:
# 4208
# 3916

# %%
sns.set(style="ticks",color_codes=True)
plt.title('checking balance in Mushroom')
sns.countplot(x=df['class'],data=df)
# Out:
# <AxesSubplot:title={'center':'checking balance in Mushroom'}, xlabel='class', ylabel='count'>

# %%
plt.figure(figsize=(14,6))
sns.catplot(x="cap-shape",hue="cap-color",col="class",data=df, kind="count",height=8,aspect=.7)

# %% [markdown]
# rom the above graph,we can see:
#
#
# 1.white coloured and bell shaped mushroom are edible
#
#
#
# 2.Red coloured and knobbed shaped mushrrom are poisonous

# %%
plt.figure(figsize=(14,6))
sns.catplot(x="odor",hue="bruises",col="class",data=df, kind="count",height=8,aspect=.7)

# %% [markdown]
# 1.Odourless and bruised mushrooms are edible
#
#
#
# 2.fishy odour with no bruises mushrroms are poisonous

# %%
plt.figure(figsize=(14,6))
sns.catplot(x="gill-size",hue="gill-color",col="class",data=df, kind="count",height=8,aspect=.7)

# %% [markdown]
# 1.chocolate and broad msuhroom are edible
#
#
#
# 2.Green coloured and narrow mushroom are poisonous

# %%
plt.figure(figsize=(14,6))
sns.catplot(x="ring-type",hue="ring-number",col="class",data=df, kind="count",height=8,aspect=.7)

# %%
plt.figure(figsize=(14,6))
sns.catplot(x="habitat",hue="population",col="class",data=df, kind="count",height=8,aspect=.7)

# %% [markdown]
# # Data Peprocessing:

# %%
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %%
df.corr()
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# ...

# %%
plt.figure(figsize=(20,17))
sns.heatmap(df.corr(), annot=True,vmin=-5.0,vmax=5.0)
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %%
plt.figure(figsize=(30,27))
sns.heatmap(round(df.describe()),annot=True,fmt="f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Model Building:

# %%
x = df.drop(['class'],axis=1)
y = df['class']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state=0, max_depth = 5)
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=0)

# %%
dt.score(x_train, y_train)
# Out:
# 0.9778403095321843

# %%
predictions = dt.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, predictions)
# Out:
# 0.9827727645611156

# %% [markdown]
# # LogisticRegression:

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# C:\Users\shaha\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr.score(x_train, y_train)
# Out:
# 0.9514597256419275

# %%
prediction1 = lr.predict(x_test)

# %%
accuracy_score(y_test, prediction1)
# Out:
# 0.9495488105004102

# %% [markdown]
# # Random forest:

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(max_depth=5)
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5)

# %%
rf.score(x_train, y_train)
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5)

# %%
prediction = rf.predict(x_test)
rf.score(x_test, y_test)
# Out:
# 0.9905660377358491

# %%
accuracy_score(y_test , prediction)
# Out:
# 0.9905660377358491

# %% [markdown]
# # conclusion:
#
#
# 1.DecisionTree accuracy = 98.27 %
#
#
# 2.LogisticRegression    = 94.95 %
#
#
# 3.RandomForest          = 99.05 %

# %% [markdown]
# # Model Saving:

# %%
import pickle

# %%
filename = 'Mushroom.data.pkl'
pickle.dump(dt, open(filename,'wb'))
